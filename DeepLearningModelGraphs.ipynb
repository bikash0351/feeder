# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Data provided by the user
data = {
    'Model': ['MLP', 'LSTM', 'GRU'],
    'MAE': [0.155, 0.467, 0.482],
    'RMSE': [0.242, 0.498, 0.499],
    'MAPE': [6.339, 14.155, 15.186],
    'R^2': [0.915, 0.014, 0.012]
}

df = pd.DataFrame(data)

# Display the DataFrame
display(df)
# Out:
#   Model    MAE   RMSE    MAPE    R^2
# 0   MLP  0.155  0.242   6.339  0.915
# 1  LSTM  0.467  0.498  14.155  0.014
# 2   GRU  0.482  0.499  15.186  0.012

# %% [markdown]
# To create a grouped bar chart, we first need to melt the DataFrame to a long format, which is more suitable for seaborn's `barplot` function. This will create columns for 'Metric' and 'Value'.

# %% [markdown]
# To visualize each metric individually across the models, we can create separate bar charts for each metric and arrange them in a grid using subplots.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming df_melted and metric_order are already defined from previous steps

# Create a figure and a set of subplots
# We'll use 2 rows and 2 columns for the 4 metrics
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(15, 10))
fig.suptitle('Deep Learning Model Performance by Metric', fontsize=18)

# Flatten the axes array for easy iteration
axes = axes.flatten()

for i, metric in enumerate(metric_order):
    # Filter data for the current metric
    metric_df = df_melted[df_melted['Metric'] == metric]

    # Create a bar plot on the current subplot
    # Address FutureWarning by explicitly setting hue and legend
    sns.barplot(x='Model', y='Value', hue='Model', data=metric_df, palette='viridis', ax=axes[i], legend=False)

    axes[i].set_title(f'{metric}', fontsize=14)
    axes[i].set_xlabel('Model', fontsize=12)
    axes[i].set_ylabel(f'{metric} Value', fontsize=12)
    axes[i].grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout(rect=[0, 0.03, 1, 0.95]) # Adjust layout to prevent title overlap
plt.show()
